# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:**
#
# **Turma:**
#
# **Tema Escolhido:**

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %%
# Classe principal: Tarefa teste 
class Tarefa:
    def __init__(self, titulo, data_vencimento, status="Pendente"):
        self.titulo = titulo
        self.data_vencimento = data_vencimento
        self.status = status

    def exibir_dados(self):
        print(f"Título: {self.titulo}")
        print(f"Data de Vencimento: {self.data_vencimento}")
        print(f"Status: {self.status}")
        print("-" * 30)

    def marcar_como_concluida(self):
        self.status = "Concluído"
        print(f"Tarefa '{self.titulo}' marcada como concluída.")

tarefa1 = Tarefa("Estudar para a prova", "2025-05-25")
tarefa2 = Tarefa("Enviar relatório do projeto", "2025-05-22")

tarefa1.exibir_dados()
tarefa2.exibir_dados()

tarefa1.marcar_como_concluida()
tarefa1.exibir_dados()

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
class Tarefa:
    def __init__(self, titulo, data_vencimento, status="Pendente"):
        self.titulo = titulo
        self.data_vencimento = data_vencimento
        self.status = status

    def exibir_dados(self):
        print(f"Título: {self.titulo}")
        print(f"Data de Vencimento: {self.data_vencimento}")
        print(f"Status: {self.status}")
        print("-" * 30)

    def marcar_como_concluida(self):
        self.status = "Concluído"
        print(f"Tarefa '{self.titulo}' marcada como concluída.")

    
    def adiar_tarefa(self, nova_data):
        print(f"Tarefa '{self.titulo}' adiada para {nova_data}.")
        self.data_vencimento = nova_data

   
    def alterar_titulo(self, novo_titulo):
        print(f"Título da tarefa alterado de '{self.titulo}' para '{novo_titulo}'.")
        self.titulo = novo_titulo

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
from datetime import date

class Tarefa:
    def __init__(self, titulo, data_vencimento):
        self.__titulo = titulo  # Atributo privado
        self.data_vencimento = data_vencimento
        self.status = "Pendente"

   
    def get_titulo(self):
        return self.__titulo

    
    def set_titulo(self, novo_titulo):
        if novo_titulo.strip() != "":
            self.__titulo = novo_titulo
        else:
            print("Erro: título não pode ser vazio!")

    
    def esta_atrasada(self):
        hoje = date.today()
        return self.status == "Pendente" and self.data_vencimento < hoje

   
    def concluir(self):
        self.status = "Concluída"

    
    def exibir(self):
        atraso = " (ATRASADA)" if self.esta_atrasada() else ""
        print(f"Tarefa: {self.__titulo} - Vencimento: {self.data_vencimento} - Status: {self.status}{atraso}")


tarefa1 = Tarefa("Estudar para a prova", date(2025, 5, 20))
tarefa1.exibir()              # Mostra a tarefa
tarefa1.concluir()            # Marca como concluída
tarefa1.set_titulo("Estudar matemática")  # Muda o título
print("Novo título:", tarefa1.get_titulo())  # Mostra o novo título

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
import sqlite3
from datetime import date


class Tarefa:
    def __init__(self, titulo, data_vencimento, status="Pendente"):
        self.titulo = titulo
        self.data_vencimento = data_vencimento
        self.status = status

    def exibir(self):
        print(f"[TAREFA] {self.titulo} - Vencimento: {self.data_vencimento} - Status: {self.status}")


class TarefaImportante(Tarefa):
    def exibir(self):
        print(f"[IMPORTANTE] 🚨 {self.titulo.upper()} - Vence em: {self.data_vencimento} - Status: {self.status}")


conn = sqlite3.connect("tarefas.db")
cursor = conn.cursor()


cursor.execute("""
CREATE TABLE IF NOT EXISTS tarefas (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    titulo TEXT,
    data_vencimento TEXT,
    status TEXT
)
""")
conn.commit()


def inserir_tarefa(tarefa):
    cursor.execute("INSERT INTO tarefas (titulo, data_vencimento, status) VALUES (?, ?, ?)",
                   (tarefa.titulo, tarefa.data_vencimento, tarefa.status))
    conn.commit()
    print("Tarefa inserida!")

s
def listar_tarefas():
    cursor.execute("SELECT * FROM tarefas")
    tarefas = cursor.fetchall()
    for id, titulo, data_venc, status in tarefas:
        print(f"[{id}] {titulo} - {data_venc} - {status}")

def deletar_tarefa(id_tarefa):
    cursor.execute("DELETE FROM tarefas WHERE id = ?", (id_tarefa,))
    conn.commit()
    print(f"Tarefa {id_tarefa} deletada!")

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
import sqlite3
from datetime import date

class Tarefa:
    def __init__(self, titulo, data_vencimento, status="Pendente"):
        self.__titulo = titulo                     # Encapsulamento: atributo privado
        self.data_vencimento = data_vencimento
        self.status = status

    def get_titulo(self):
        return self.__titulo

   
    def set_titulo(self, novo_titulo):
        if novo_titulo.strip():
            self.__titulo = novo_titulo
        else:
            print("Erro: título inválido.")

    
    def esta_atrasada(self):
        hoje = date.today()
        return self.status == "Pendente" and self.data_vencimento < hoje

   a
    def concluir(self):
        self.status = "Concluída"

    
    def exibir(self):
        atraso = " (ATRASADA)" if self.esta_atrasada() else ""
        print(f"[TAREFA] {self.__titulo} - Vencimento: {self.data_vencimento} - Status: {self.status}{atraso}")


class TarefaImportante(Tarefa):
    def exibir(self):
        atraso = " (ATRASADA)" if self.esta_atrasada() else ""
        print(f"[IMPORTANTE] 🚨 {self.get_titulo().upper()} - Vencimento: {self.data_vencimento} - Status: {self.status}{atraso}")


conn = sqlite3.connect("tarefas.db")
cursor = conn.cursor()


cursor.execute("""
CREATE TABLE IF NOT EXISTS tarefas (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    titulo TEXT,
    data_vencimento TEXT,
    status TEXT,
    importante INTEGER
)
""")
conn.commit()


def inserir_tarefa(tarefa, importante=False):
    cursor.execute("INSERT INTO tarefas (titulo, data_vencimento, status, importante) VALUES (?, ?, ?, ?)",
                   (tarefa.get_titulo(), tarefa.data_vencimento, tarefa.status, int(importante)))
    conn.commit()
    print("✅ Tarefa inserida com sucesso!")


def listar_tarefas():
    cursor.execute("SELECT * FROM tarefas")
    tarefas = cursor.fetchall()
    if not tarefas:
        print("Nenhuma tarefa cadastrada.")
        return

    print("\n📋 Tarefas:")
    for id, titulo, data_venc, status, importante in tarefas:
        if importante:
            tarefa = TarefaImportante(titulo, data_venc, status)
        else:
            tarefa = Tarefa(titulo, data_venc, status)
        print(f"ID: {id} → ", end="")
        tarefa.exibir()


def concluir_tarefa(id_tarefa):
    cursor.execute("UPDATE tarefas SET status = 'Concluída' WHERE id = ?", (id_tarefa,))
    conn.commit()
    print(f"✅ Tarefa {id_tarefa} marcada como concluída.")

def deletar_tarefa(id_tarefa):
    cursor.execute("DELETE FROM tarefas WHERE id = ?", (id_tarefa,))
    conn.commit()
    print(f"🗑️ Tarefa {id_tarefa} deletada.")


def menu():
    while True:
        print("\n===== MENU =====")
        print("1 - Adicionar Tarefa")
        print("2 - Listar Tarefas")
        print("3 - Concluir Tarefa")
        print("4 - Deletar Tarefa")
        print("0 - Sair")
        opcao = input("Escolha: ")

        if opcao == "1":
            titulo = input("Título: ")
            data = input("Data de vencimento (AAAA-MM-DD): ")
            tipo = input("É importante? (s/n): ").lower()
            if tipo == "s":
                tarefa = TarefaImportante(titulo, data)
                inserir_tarefa(tarefa, importante=True)
            else:
                tarefa = Tarefa(titulo, data)
                inserir_tarefa(tarefa)

        elif opcao == "2":
            listar_tarefas()

        elif opcao == "3":
            id_tarefa = input("ID da tarefa para concluir: ")
            concluir_tarefa(id_tarefa)

        elif opcao == "4":
            id_tarefa = input("ID da tarefa para deletar: ")
            deletar_tarefa(id_tarefa)

        elif opcao == "0":
            print("Saindo... 👋")
            break

        else:
            print("Opção inválida.")


if __name__ == "__main__":
    print("Bem-vindo ao Gerenciador de Tarefas!")
    menu()
    conn.close()
